# %% [markdown]
# # Projet : réaliser une étude sur les produits alimentaires

# %% [markdown]
# ## 1 - Contexte

# %% [markdown]
# Vous réalisez une mission "UFC-Que Choisir". Cette association vous demande de réaliser une étude
# sur la qualité des produits alimentaires mis à disposition des consommateurs par les marques. Cette étude a vocation à aider les consommateurs dans leurs choix.

# %% [markdown]
# L'objectif est d'analyser les marques sur au moins les critères suivants : la qualité nutritionnelle, l'impact environnemental, la part des produits biologiques.

# %% [markdown]
# Pour cela, vous proposer d'utiliser les données de l'application Yuka

# %% [markdown]
# Voici une liste des questions que se pose l'association :
#
# - Quelles sont les marques qui jouent le jeu et affichent le nutriscore ? Lesquelles ne le font pas?
#
# - Quelles sont les marques qui ont le plus recours aux additifs nocifs
#
# - Quelles sont les marques qui présentent des produits avec la meilleure qualité nutritionnelle ? Les pires ?
#
# - Quelles sont les marques qui jouent le jeu et affichent l'ecosore ? Lesquelles ne le font pas?
#
# - Quelles sont les marques qui semblent le plus respectueuses de l'environnement ? le moins?
#
# - Quelles sont les marques qui proposent essentiellement des produits biologiques ?
#
# - Observe-t-on une corrélation entre le caratère bio des produits et la qualité nutritionnelle ?
#
# - Observe-t-on une corrélation entre le caratère bio des produits et l'aspect envionnemental ?
#
# - Observe-t-on une corrélation entre la la qualité nutritionnelle et l'aspec envionnemental ?
#
# - Quelles marques faut-il recommander ?
#
# - Quelles marques ne faut-il surtout pas recommander ?

# %% [markdown]
# ## 2 - Données

# %% [markdown]
# 3 fichiers issues de l'application Yuka sont à exploiter pour réaliser l'analyse.

# %% [markdown]
# Agriculture_biologique_final.csv
#
# Qualite nutritionnelle_final.csv
#
# Impact environnemental_final.csv

# %% [markdown]
# Voici le lien pour récupérer les fichiers

# %% [markdown]
# https://www.dropbox.com/sh/pwsv4coi2sbbhyo/AABJ81-xWu3K2Cl0DOCmwbGsa?dl=0

# %% [markdown]
# ## 3 - Consignes

# %% [markdown]
# Travail de groupe de 3 personnes.
#
# Pour l'évaluation CC, chaque groupe doit livrer à la fin des sessions :
#
#     - un rapport synthétisant l'analyse faite et les conculusions obtenues
#
#     - un notebook nettoyé et commenté

# %% [markdown]
# ## 4 - Contraintes
#
# Votre analyse doit inclure des analyses univariées et multivariées

# %% [markdown]
# ## 5 - Préparation de l'environnement

# %%
# Import de la librairie Pandas
import pandas as pd

# Import de la librairie matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## 6 - A vous de jouer¶

# %% [markdown]
# Inspirez-vous du TP vu en cours

# %%
bio = pd.read_csv("Agriculture_biologique_final.csv", sep ="\t")
impact_envi = pd.read_csv("Impact environnemental_final.csv", sep ="\t")
qualité_nutriti = pd.read_csv("Qualite nutritionnelle_final.csv", sep ="\t")
# Out:
# /var/folders/34/s_jkn01x6n1fms6ncbz482wc0000gn/T/ipykernel_6468/3329478499.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   impact_envi = pd.read_csv("Impact environnemental_final.csv", sep ="\t")
# /var/folders/34/s_jkn01x6n1fms6ncbz482wc0000gn/T/ipykernel_6468/3329478499.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   qualité_nutriti = pd.read_csv("Qualite nutritionnelle_final.csv", sep ="\t")

# %% [markdown]
# # EXERCICE

# %% [markdown]
# ## Quelles sont les marques qui jouent le jeu et affichent le nutriscore ? Lesquelles ne le font pas?

# %%
#importe le dataframe en copy pour ne pas toucher l'original
quest_1 = qualité_nutriti.copy()
# je conserve uniquement les colonnes qui m'interesse
quest_1 = quest_1[["brands_tags", "nutriscore_grade", "code" ]]
# Supprime les doublons
quest_1 = quest_1.drop_duplicates()
# Je supprime les NaN dans la colonne brands_tags
quest_1.dropna(subset=['brands_tags'], inplace=True)
# Je remplace les Nan de la colonnes "Nutri_score" par NC (Non Communiqué)
quest_1.nutriscore_grade = quest_1.nutriscore_grade.fillna('NC')
# Ont fait un pivot table avec le margins
quest_1 = quest_1.pivot_table(index='brands_tags', columns='nutriscore_grade', aggfunc='count', values='code', margins=True)
# Je conserve les marques qui ont plus de 500 produit
quest_1 = quest_1[quest_1.All>500]
# Je crée une colonne "Ratio_NC" qui va me calculer le ratio de NC sur ALL
quest_1["ratio_NC"] = round(quest_1.NC/quest_1.All*100,2)

# %% [markdown]
# * **Les marques qui joue + le jeu sont :**

# %%
quest_1.sort_values(by='ratio_NC', ascending = True).head()
# Out:
# nutriscore_grade            NC      a      b      c      d      e   All  \
# brands_tags
# u-saveurs,u               59.0   33.0   31.0  107.0  180.0   94.0   504
# belle-france             259.0  257.0  184.0  334.0  373.0  251.0  1658
# carrefour-bio,carrefour   83.0  136.0   63.0   91.0   94.0   55.0   522
# monique-ranou            133.0   35.0   77.0  130.0  133.0   94.0   602
# la-nouvelle-agriculture  230.0  505.0  233.0   25.0   28.0    5.0  1026
#
# nutriscore_grade         ratio_NC
# brands_tags
# u-saveurs,u                 11.71
# belle-france                15.62
# carrefour-bio,carrefour     15.90
# monique-ranou               22.09
# la-nouvelle-agriculture     22.42

# %% [markdown]
# * **Les marques qui joue - le jeu sont :**

# %%
quest_1.sort_values(by='ratio_NC', ascending = False).head()
# Out:
# nutriscore_grade     NC     a     b     c     d     e   All  ratio_NC
# brands_tags
# palais-des-thes   877.0   NaN  32.0  13.0   3.0   2.0   927     94.61
# ducros            557.0  13.0  10.0   8.0  27.0   6.0   621     89.69
# maggi             496.0   5.0  26.0  35.0  36.0  10.0   608     81.58
# myprotein         873.0  47.0  39.0  37.0  65.0  23.0  1084     80.54
# prozis            465.0  35.0  43.0  42.0  29.0   8.0   622     74.76

# %% [markdown]
# ## Quelles sont les marques qui ont le plus recours aux additifs nocifs

# %%
# Importe le dataframe en copy() pour garder la version originile
quest_2 = qualité_nutriti.copy()
# Supprime les doublons
quest_2 = quest_2.drop_duplicates()
# Je conserve uniquement les colonnes qui m'interresse
quest_2 = quest_2[['code', 'product_name', 'brands_tags', 'nb_nocif']]
# Je regroupe par "brands_tags" et sum par nb_nocif
quest_2.groupby("brands_tags").sum("nb_nocif").sort_values(by ='nb_nocif',ascending = False).head(10)
# Out:
#                   nb_nocif
# brands_tags
# sodastream            29.0
# nestle,sveltesse      10.0
# a-rom                  9.0
# dove                   8.0
# nestle                 7.0
# schweppes              7.0
# freeway                6.0
# steff                  4.0
# fruiss                 4.0
# san-benedetto          4.0

# %% [markdown]
# ## Quelles sont les marques qui présentent des produits avec la meilleure qualité nutritionnelle ? Les pires ?

# %%
# Je recupère le tableau de de la premiere question
quest_3 = quest_1.copy()

# Ont crée des colonnes pour faire des ratio sur chaque grades
quest_3["ratio_A"] = round(quest_3.a/quest_3.All*100,2)
quest_3["ratio_B"] = round(quest_3.b/quest_3.All*100,2)
quest_3["ratio_C"] = round(quest_3.c/quest_3.All*100,2)
quest_3["ratio_D"] = round(quest_3.d/quest_3.All*100,2)
quest_3["ratio_E"] = round(quest_3.e/quest_3.All*100,2)


# Scoring par grade
# A = 5 points, B = 4 points, C = 3 points, D = 2 points, E = 1 point
# Ont recupére une note sur 500
quest_3["Note_Ratio"] = quest_3["ratio_A"] * 5 + quest_3["ratio_B"] * 4 + quest_3["ratio_C"] * 3 + quest_3["ratio_D"] * 2 + quest_3["ratio_E"] * 1

# %% [markdown]
# * **Les marques qui presente des produits avec la meilleure qualité nutritionnelle sont :**

# %%
# Trie par Note_Ratio
quest_3.sort_values(by = "Note_Ratio", ascending = False).head(11)
# Out:
# nutriscore_grade            NC      a      b      c     d     e   All  \
# brands_tags
# la-nouvelle-agriculture  246.0  560.0  261.0   27.0  32.0   5.0  1131
# cereal-bio                86.0  147.0   36.0   29.0   9.0  10.0   317
# tendre-plus               68.0   12.0  189.0   62.0  24.0   2.0   357
# saint-eloi               176.0  217.0   63.0   20.0   8.0   1.0   485
# marie                     51.0   38.0  111.0   82.0  67.0   5.0   354
# jacquet                   96.0   85.0   78.0   28.0  16.0   2.0   305
# delisse,marque-repere     51.0   25.0   82.0  145.0  38.0   5.0   346
# markal                   149.0  178.0   30.0   17.0  21.0   6.0   401
# carrefour-bio,carrefour   88.0  141.0   64.0   96.0  95.0  58.0   542
# jardin-bio,lea-nature     93.0  104.0   58.0   46.0  44.0  21.0   366
# casino-bio,casino         86.0  114.0   65.0   63.0  82.0  43.0   453
#
# nutriscore_grade         ratio_NC  ratio_A  ratio_B  ratio_C  ratio_D  \
# brands_tags
# la-nouvelle-agriculture     21.75    49.51    23.08     2.39     2.83
# cereal-bio                  27.13    46.37    11.36     9.15     2.84
# tendre-plus                 19.05     3.36    52.94    17.37     6.72
# saint-eloi                  36.29    44.74    12.99     4.12     1.65
# marie                       14.41    10.73    31.36    23.16    18.93
# jacquet                     31.48    27.87    25.57     9.18     5.25
# delisse,marque-repere       14.74     7.23    23.70    41.91    10.98
# markal                      37.16    44.39     7.48     4.24     5.24
# carrefour-bio,carrefour     16.24    26.01    11.81    17.71    17.53
# jardin-bio,lea-nature       25.41    28.42    15.85    12.57    12.02
# casino-bio,casino           18.98    25.17    14.35    13.91    18.10
#
# nutriscore_grade         ratio_E  Note_Ratio
# brands_tags
# la-nouvelle-agriculture     0.44      353.14
# cereal-bio                  3.15      313.57
# tendre-plus                 0.56      294.67
# saint-eloi                  0.21      291.53
# marie                       1.41      287.84
# jacquet                     0.66      280.33
# delisse,marque-repere       1.45      280.09
# markal                      1.50      276.57
# carrefour-bio,carrefour    10.70      276.18
# jardin-bio,lea-nature       5.74      272.99
# casino-bio,casino           9.49      270.67

# %% [markdown]
# * **Les marques qui presente des produits avec la pire qualité nutritionnelle sont :**

# %%
# Trie par Note_Ratio
quest_3.sort_values(by = "Note_Ratio", ascending = True).head(11)
# Out:
# nutriscore_grade     NC     a     b     c     d     e   All  ratio_NC  \
# brands_tags
# bledina           293.0   5.0   5.0   1.0   1.0   3.0   308     95.13
# hipp              401.0   6.0   5.0   5.0   3.0   2.0   422     95.02
# ducros            649.0  13.0  10.0   8.0  27.0   6.0   713     91.02
# sainte-lucie      455.0   5.0   9.0  19.0  38.0   9.0   535     85.05
# teisseire         277.0   7.0   9.0  14.0  16.0  27.0   350     79.14
# maggi             552.0   6.0  27.0  35.0  40.0  10.0   670     82.39
# albert-heijn      268.0  11.0  12.0   7.0  11.0  20.0   329     81.46
# hema              538.0  10.0  17.0  25.0  71.0  90.0   751     71.64
# myprotein         978.0  50.0  39.0  39.0  65.0  23.0  1194     81.91
# continente        246.0   6.0   6.0  21.0  32.0  21.0   332     74.10
# marque-repere     358.0  25.0  10.0  16.0  26.0  12.0   447     80.09
#
# nutriscore_grade  ratio_A  ratio_B  ratio_C  ratio_D  ratio_E  Note_Ratio
# brands_tags
# bledina              1.62     1.62     0.32     0.32     0.97       17.15
# hipp                 1.42     1.18     1.18     0.71     0.47       17.25
# ducros               1.82     1.40     1.12     3.79     0.84       26.48
# sainte-lucie         0.93     1.68     3.55     7.10     1.68       37.90
# teisseire            2.00     2.57     4.00     4.57     7.71       49.13
# maggi                0.90     4.03     5.22     5.97     1.49       49.71
# albert-heijn         3.34     3.65     2.13     3.34     6.08       50.45
# hema                 1.33     2.26     3.33     9.45    11.98       56.56
# myprotein            4.19     3.27     3.27     5.44     1.93       56.65
# continente           1.81     1.81     6.33     9.64     6.33       60.89
# marque-repere        5.59     2.24     3.58     5.82     2.68       61.97

# %% [markdown]
# ## Quelles sont les marques qui jouent le jeu et affichent l'ecosore ? Lesquelles ne le font pas?

# %%
#importe le dataframe en copy pour ne pas toucher l'original
quest_4 = impact_envi.copy()
# je conserve uniquement les colonnes qui m'interesse
quest_4 = quest_4[["code", "product_name", "brands_tags", "ecoscore_grade"]]
# Je supprime les NaN dans la colonne brands_tags
quest_4.dropna(subset=['brands_tags'], inplace=True)
# Je transforme toute les valeurs différente de a,b,c,d,e par NC
quest_4.loc[~quest_4['ecoscore_grade'].isin(['a', 'b', 'c', 'd', 'e']), 'ecoscore_grade'] = 'NC'
# Ont fait un pivot table avec le margins
quest_4 = quest_4.pivot_table(index='brands_tags', columns='ecoscore_grade', aggfunc='count', values='code', margins=True)
# Je conserve les marques qui ont plus de 300 produit
quest_4 = quest_4[quest_4.All>300]
# Je crée une colonne "Ratio_NC" qui va me calculer le ratio de NC sur ALL
quest_4["ratio_NC"] = round(quest_4.NC/quest_4.All*100,2)

# %% [markdown]
# * **Les marques qui joue + le jeu sont :**

# %%
quest_4.sort_values(by='ratio_NC', ascending = True).head()
# Out:
# ecoscore_grade              NC     a      b      c      d      e   All  \
# brands_tags
# la-belle-iloise           41.0   8.0   26.0   40.0  131.0   95.0   341
# saveurs-de-nos-regions    59.0   8.0   32.0   47.0  193.0   46.0   385
# la-nouvelle-agriculture  189.0   1.0    4.0   87.0  779.0   71.0  1131
# belle-france             329.0  64.0  437.0  279.0  338.0  227.0  1674
# carrefour-bio,carrefour  110.0  83.0  172.0   93.0   56.0   28.0   542
#
# ecoscore_grade           ratio_NC
# brands_tags
# la-belle-iloise             12.02
# saveurs-de-nos-regions      15.32
# la-nouvelle-agriculture     16.71
# belle-france                19.65
# carrefour-bio,carrefour     20.30

# %% [markdown]
# * **Les marques qui joue - le jeu sont :**

# %%
quest_4.sort_values(by='ratio_NC', ascending = False).head()
# Out:
# ecoscore_grade       NC     a     b     c     d     e   All  ratio_NC
# brands_tags
# coca-cola         508.0   NaN   3.0   1.0   1.0   NaN   513     99.03
# schweppes         326.0   NaN   1.0   4.0   3.0   NaN   334     97.60
# myprotein        1127.0   NaN  12.0  16.0  26.0  13.0  1194     94.39
# palais-des-thes   977.0  17.0  46.0   2.0   4.0   NaN  1046     93.40
# mentos            310.0   NaN   1.0   NaN   5.0  17.0   333     93.09

# %% [markdown]
# ## Quelles sont les marques qui semblent le plus respectueuses de l'environnement ? le moins?

# %%
# Je recupère le tableau de de la premiere question
quest_5 = quest_4.copy()

# Ont crée des colonnes pour faire des ratio sur chaque grades
quest_5["ratio_A"] = round(quest_5.a/quest_5.All*100,2)
quest_5["ratio_B"] = round(quest_5.b/quest_5.All*100,2)
quest_5["ratio_C"] = round(quest_5.c/quest_5.All*100,2)
quest_5["ratio_D"] = round(quest_5.d/quest_5.All*100,2)
quest_5["ratio_E"] = round(quest_5.e/quest_5.All*100,2)


# Scoring par grade
# A = 5 points, B = 4 points, C = 3 points, D = 2 points, E = 1 point
# Ont recupére une note sur 500
quest_5["Note_Ratio"] = quest_5["ratio_A"] * 5 + quest_5["ratio_B"] * 4 + quest_5["ratio_C"] * 3 + quest_5["ratio_D"] * 2 + quest_5["ratio_E"] * 1

# %% [markdown]
# * **Les marques les + respectueuse de l'environnement :**

# %%
quest_5.sort_values(by = "Note_Ratio", ascending = False).head(11)
# Out:
# ecoscore_grade                NC      a      b      c      d      e   All  \
# brands_tags
# jardin-bio,lea-nature      112.0   88.0  108.0   47.0   10.0    1.0   366
# carrefour-bio,carrefour    110.0   83.0  172.0   93.0   56.0   28.0   542
# u-bio,u                    154.0  123.0  158.0  116.0   56.0   11.0   618
# jacquet                    115.0   47.0  135.0    2.0    3.0    3.0   305
# casino-bio,casino          124.0   61.0  148.0   54.0   47.0   19.0   453
# bio-village,marque-repere  264.0   91.0  274.0  140.0   74.0   23.0   866
# delisse,marque-repere      116.0   20.0  124.0   42.0   24.0   20.0   346
# belle-france               329.0   64.0  437.0  279.0  338.0  227.0  1674
# grand-jury                 195.0   30.0  167.0  139.0  112.0   72.0   715
# pouce,auchan                87.0   11.0   79.0   65.0   59.0   39.0   340
# materne                    188.0   48.0  137.0   10.0   31.0    3.0   417
#
# ecoscore_grade             ratio_NC  ratio_A  ratio_B  ratio_C  ratio_D  \
# brands_tags
# jardin-bio,lea-nature         30.60    24.04    29.51    12.84     2.73
# carrefour-bio,carrefour       20.30    15.31    31.73    17.16    10.33
# u-bio,u                       24.92    19.90    25.57    18.77     9.06
# jacquet                       37.70    15.41    44.26     0.66     0.98
# casino-bio,casino             27.37    13.47    32.67    11.92    10.38
# bio-village,marque-repere     30.48    10.51    31.64    16.17     8.55
# delisse,marque-repere         33.53     5.78    35.84    12.14     6.94
# belle-france                  19.65     3.82    26.11    16.67    20.19
# grand-jury                    27.27     4.20    23.36    19.44    15.66
# pouce,auchan                  25.59     3.24    23.24    19.12    17.35
# materne                       45.08    11.51    32.85     2.40     7.43
#
# ecoscore_grade             ratio_E  Note_Ratio
# brands_tags
# jardin-bio,lea-nature         0.27      282.49
# carrefour-bio,carrefour       5.17      280.78
# u-bio,u                       1.78      277.99
# jacquet                       0.98      259.01
# casino-bio,casino             4.19      258.74
# bio-village,marque-repere     2.66      247.38
# delisse,marque-repere         5.78      228.34
# belle-france                 13.56      227.49
# grand-jury                   10.07      214.15
# pouce,auchan                 11.47      212.69
# materne                       0.72      211.73

# %% [markdown]
# * **Les marques les - respectueuse de l'environnement :**

# %%
quest_5.sort_values(by = "Note_Ratio", ascending = True).head(11)
# Out:
# ecoscore_grade      NC     a      b      c      d      e   All  ratio_NC  \
# brands_tags
# maggi            620.0   7.0   17.0    4.0    3.0   19.0   670     92.54
# prozis           598.0   1.0   13.0   23.0   17.0    9.0   661     90.47
# nescafe          269.0   1.0    5.0    5.0   18.0   66.0   364     73.90
# bledina          275.0   5.0   21.0    1.0    4.0    2.0   308     89.29
# albert-heijn     278.0   4.0   10.0   15.0   11.0   11.0   329     84.50
# hema             596.0   2.0   45.0   21.0   29.0   58.0   751     79.36
# marque-repere    366.0   6.0   22.0   12.0   28.0   13.0   447     81.88
# cemoi            234.0   1.0   13.0   10.0   14.0   66.0   338     69.23
# waitrose         235.0   1.0    8.0   17.0   32.0   16.0   309     76.05
# nestle          2207.0  25.0  190.0  164.0  123.0  154.0  2863     77.09
# conad            268.0   1.0   26.0    8.0   38.0   10.0   351     76.35
#
# ecoscore_grade  ratio_A  ratio_B  ratio_C  ratio_D  ratio_E  Note_Ratio
# brands_tags
# maggi              1.04     2.54     0.60     0.45     2.84       20.90
# prozis             0.15     1.97     3.48     2.57     1.36       25.57
# nescafe            0.27     1.37     1.37     4.95    18.13       38.97
# bledina            1.62     6.82     0.32     1.30     0.65       39.59
# albert-heijn       1.22     3.04     4.56     3.34     3.34       41.96
# hema               0.27     5.99     2.80     3.86     7.72       49.15
# marque-repere      1.34     4.92     2.68     6.26     2.91       49.85
# cemoi              0.30     3.85     2.96     4.14    19.53       53.59
# waitrose           0.32     2.59     5.50    10.36     5.18       54.36
# nestle             0.87     6.64     5.73     4.30     5.38       62.08
# conad              0.28     7.41     2.28    10.83     2.85       62.39

# %% [markdown]
# ## Quelles sont les marques qui proposent essentiellement des produits biologiques ?

# %%
#J'appelle le dataframe
quest_6 = qualité_nutriti.copy()
# je conserve uniquement les colonnes qui m'interesse
quest_6  = quest_6[["code", "product_name", "quantity", "brands_tags", "serving_size"]]
# je merge les deux datframe
quest_6 = quest_6.merge(bio, on=["product_name", "brands_tags", "serving_size"], how='outer')
# Supprime les doublons
quest_6 = quest_6.drop_duplicates()
# Je remplace les NaN par False
quest_6['est_bio'].fillna(False, inplace=True)
# Je converse uniqumement les colonnes qui m'interesse
quest_6 = quest_6[["brands_tags","est_bio"]]
# Je regroupe par la colonne [brands_tags] est sum + count sur la colonne [est_bio]
quest_6 = quest_6.groupby(by="brands_tags").est_bio.agg([sum,"count"]).sort_values("sum", ascending=False)
# je fait un ratio
quest_6["ratio%"] = quest_6["sum"]/quest_6["count"]*100
# Je garde uniquement les marques qui ont plus de 300 produits dans le catalogues
quest_6 = quest_6[quest_6["count"] >300]
# je trie les valeur du grand au plus petit
quest_6.sort_values("ratio%", ascending=False)
# Out:
#                            sum  count      ratio%
# brands_tags
# jardin-bio,lea-nature      364    364  100.000000
# casino-bio,casino          444    445   99.775281
# carrefour-bio,carrefour    519    522   99.425287
# u-bio,u                    611    620   98.548387
# bio-village,marque-repere  846    862   98.143852
# ...                        ...    ...         ...
# comtesse-du-barry            0    338    0.000000
# eco                          0    632    0.000000
# delisse,marque-repere        0    343    0.000000
# haagen-dazs                  0    371    0.000000
# haribo                       0   1441    0.000000
#
# [151 rows x 3 columns]
